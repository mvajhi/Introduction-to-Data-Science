# %%
from sklearn.datasets import load_diabetes
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from scipy import stats
from sklearn.linear_model import LinearRegression

# %%
diabetes = load_diabetes(scaled=False)
diabetes.data.shape
# Out:
# (442, 10)

# %%
diabetes.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
df = pd.DataFrame(diabetes.data)
df.columns = diabetes.feature_names
df[:10]
# Out:
#     age  sex   bmi     bp     s1     s2    s3    s4      s5    s6
# 0  59.0  2.0  32.1  101.0  157.0   93.2  38.0  4.00  4.8598  87.0
# 1  48.0  1.0  21.6   87.0  183.0  103.2  70.0  3.00  3.8918  69.0
# 2  72.0  2.0  30.5   93.0  156.0   93.6  41.0  4.00  4.6728  85.0
# 3  24.0  1.0  25.3   84.0  198.0  131.4  40.0  5.00  4.8903  89.0
# 4  50.0  1.0  23.0  101.0  192.0  125.4  52.0  4.00  4.2905  80.0
# 5  23.0  1.0  22.6   89.0  139.0   64.8  61.0  2.00  4.1897  68.0
# 6  36.0  2.0  22.0   90.0  160.0   99.6  50.0  3.00  3.9512  82.0
# 7  66.0  2.0  26.2  114.0  255.0  185.0  56.0  4.55  4.2485  92.0
# 8  60.0  2.0  32.1   83.0  179.0  119.4  42.0  4.00  4.4773  94.0
# 9  29.0  1.0  30.0   85.0  180.0   93.4  43.0  4.00  5.3845  88.0

# %%
df.dtypes
# Out:
# age    float64
# sex    float64
# bmi    float64
# bp     float64
# s1     float64
# s2     float64
# s3     float64
# s4     float64
# s5     float64
# s6     float64
# dtype: object

# %%
missing_data = df.isnull().sum()
print(missing_data)
# no missing data in the dataset
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
scaler = StandardScaler()
normalized_data = scaler.fit_transform(df)
df_normalized = pd.DataFrame(normalized_data, columns=df.columns)
df_normalized
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.800500  1.065488  1.297088  0.459841 -0.929746 -0.732065 -0.912451
# 1   -0.039567 -0.938537 -1.082180 -0.553505 -0.177624 -0.402886  1.564414
# 2    1.793307  1.065488  0.934533 -0.119214 -0.958674 -0.718897 -0.680245
# 3   -1.872441 -0.938537 -0.243771 -0.770650  0.256292  0.525397 -0.757647
# 4    0.113172 -0.938537 -0.764944  0.459841  0.082726  0.327890  0.171178
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.876870  1.065488  0.413360  1.256040 -0.119769 -0.053957 -0.602843
# 438 -0.115937  1.065488 -0.334410 -1.422086  1.037341  1.664355 -0.602843
# 439  0.876870  1.065488 -0.334410  0.363573 -0.785107 -0.290965 -0.525441
# 440 -0.956004 -0.938537  0.821235  0.025550  0.343075  0.321306 -0.602843
# 441 -0.956004 -0.938537 -1.535374 -1.711613  1.760535  0.584649  3.654268
#
#            s4        s5        s6
# 0   -0.054499  0.418531 -0.370989
# 1   -0.830301 -1.436589 -1.938479
# 2   -0.054499  0.060156 -0.545154
# 3    0.721302  0.476983 -0.196823
# 4   -0.054499 -0.672502 -0.980568
# ..        ...       ...       ...
# 437 -0.054499  0.655787  0.151508
# 438  0.721302 -0.380819  0.935254
# 439 -0.232934 -0.985649  0.325674
# 440  0.558384  0.936163 -0.545154
# 441 -0.830301 -0.088752  0.064426
#
# [442 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df_normalized, diabetes.target, test_size=0.05, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape,diabetes.target.shape)
# Out:
# (419, 10) (23, 10) (419,) (23,) (442,)

# %%
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

def mean_absolute_error(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))

def root_mean_squared_error(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def r2_score(y_true, y_pred):
    correlation_matrix = np.corrcoef(y_true, y_pred)
    correlation_xy = correlation_matrix[0,1]
    r_squared = correlation_xy**2
    return r_squared

# %%
model = LinearRegression()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)
print("R^2:", r2)
# Out:
# Mean Squared Error: 3516.1108664162202
# Mean Absolute Error: 49.27832027864404
# Root Mean Squared Error: 59.296803171977324
# R^2: 0.5739039654245792

# %%
y_pred = model.predict(X_train)

mse = mean_squared_error(y_train, y_pred)
mae = mean_absolute_error(y_train, y_pred)
rmse = root_mean_squared_error(y_train, y_pred)
r2 = r2_score(y_train, y_pred)
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)
print("R^2:", r2)
# Out:
# Mean Squared Error: 2831.219526387828
# Mean Absolute Error: 42.96383748248952
# Root Mean Squared Error: 53.20920527867173
# R^2: 0.5135880257685108

# %%
import statsmodels.api as sm
model = sm.OLS(y_train,X_train)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.102
# Model:                            OLS   Adj. R-squared (uncentered):              0.080
# Method:                 Least Squares   F-statistic:                              4.650
# Date:                Sat, 27 Apr 2024   Prob (F-statistic):                    2.71e-06
# Time:                        14:32:33   Log-Likelihood:                         -2721.3
# No. Observations:                 419   AIC:                                      5463.
# Df Residuals:                     409   BIC:                                      5503.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age            1.5426      8.802      0.175      0.861     -15.761      18.846
# sex          -14.6748      9.033     -1.624      0.105     -32.432       3.083
# bmi           24.1919      9.834      2.460      0.014       4.861      43.523
# bp            17.4253      9.474      1.839      0.067      -1.198      36.048
# s1           -50.0028     60.351     -0.829      0.408    -168.640      68.634
# s2            26.6163     48.999      0.543      0.587     -69.705     122.938
# s3            10.8124     30.751      0.352      0.725     -49.637      71.262
# s4            17.5150     23.826      0.735      0.463     -29.321      64.351
# s5            34.3271     24.936      1.377      0.169     -14.692      83.346
# s6             1.7981      9.606      0.187      0.852     -17.086      20.682
# ==============================================================================
# Omnibus:                        0.364   Durbin-Watson:                   0.207
# Prob(Omnibus):                  0.834   Jarque-Bera (JB):                0.485
# Skew:                           0.035   Prob(JB):                        0.785
# Kurtosis:                       2.849   Cond. No.                         21.3
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
